# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandre77777/computer_math/blob/main/8.%20%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%B0%D0%B2%D1%82%D0%BE%D0%BC%D0%B0%D1%82%D0%B8%D0%B7%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%BD%D0%BE%D0%B9%20%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC%D1%8B%20%D0%BF%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%20%D0%BA%D0%BE%D0%BE%D1%80%D0%B4%D0%B8%D0%BD%D0%B0%D1%82%D0%BD%D1%8B%D1%85%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%968_%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_%D0%B0%D0%B2%D1%82%D0%BE%D0%BC%D0%B0%D1%82%D0%B8%D0%B7%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%BD%D0%BE%D0%B9_%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC%D1%8B_%D0%BF%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BA%D0%BE%D0%BE%D1%80%D0%B4%D0%B8%D0%BD%D0%B0%D1%82%D0%BD%D1%8B%D1%85_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа №8. Разработка автоматизированной системы преобразования координатных данных

# %% [markdown]
# # 1. Реализация генератора синтетического набора данных

# %%
import csv
import random
import string

def generate_csv(file_path, num_rows):
    # Генерация случайного имени
    def random_name(length=5):
        letters = string.ascii_letters + string.digits
        return ''.join(random.choice(letters) for i in range(length))

    # Генерация случайного числа больше 100000
    def random_number():
        return random.randint(100000000, 999999000)/1000

    # Создание и запись в CSV-файл
    with open(file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Name', 'X', 'Y', 'Z'])  # Заголовки столбцов

        for _ in range(num_rows):
            writer.writerow([random_name(), random_number(), random_number(), random_number()])

# Пример использования функции
generate_csv('example.csv', 10)

# %% [markdown]
# ## 2. Реализация алгоритма вычислений

# %% [markdown]
# ## Параметры перехода:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Формирование файла с параметрами перехода

# %% [markdown]
# [Документация json](https://ru-brightdata.com/blog/how-tos-ru/parse-json-data-with-python)

# %%
import json

# Задаем параметры перехода в виде словаря
parameters = {
  "ПЗ-90": {
    "ΔX": "значение смещения по оси X",
    "ΔY": "значение смещения по оси Y",
    "ΔZ": "значение смещения по оси Z",
    "ωx": "значение углового элемента трансформации по оси X",
    "ωy": "значение углового элемента трансформации по оси Y",
    "ωz": "значение углового элемента трансформации по оси Z",
    "m": "значение масштабного коэффициента"
  }

  # и так далее
}

# Путь к файлу для сохранения
file_path = '/parameters.json'

# Сохранение данных в JSON файл
with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(parameters, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Математический аппарат:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Значения *w* необходимо перевести в радианы из угловых секунд!

# %% [markdown]
# ### Напишите функцию, получающую на вход DataFrame или файл csv с координатами в начальной системе, тип начальной системы, тип конечной системы, путь к файлу с параметрами перехода, а также значение опционального параметра для сохранения результата

# %% [markdown]
#  - Функция должна осуществлять преобразования по формулам, представленным выше. Функция возвращает DataFrame или опционально сохраняет вычисления в текстовый файл.
#
#  - Вычисления должны производиться с использованием библиотеки SymPy:

# %%
# Ваш код

# %% [markdown]
# # 3. Тестирование готового решения

# %% [markdown]
# **Контроль** (доускаются незначительные различия)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Приведите примеры всех вариантов работы вашей функции

# %%
# Ваш код

# %% [markdown]
# # 4. Автоматизированное формирование отчета о результатах вычислений в формате Microsoft Office Word
#
# По примеру из теории (п. 4) сформируйте отчет о результатах вычислений в формате docx.
#
# В отчете обязательно должны быть разделы (каждый пункт в отдельном разделе!):
# 1. Общая формула по которой производились вычисления (см. п. Математический аппарат);
# 2. Общая формула с подставленными в нее параметрами перехода между выбранными системами. Записать в отдельном разделе;
# 3. Пример последовательных преобразований (вычислений) одного (первого) набора кординат X, Y, Z. (Общая формула -> Подстановка параметров перехода -> Подстановка начальных координат -> Вычесленные конечные координаты)
# 4. Таблица с координатами до и после преобразования и общая статистика.

# %%
# Ваш код
